# %% [markdown]
# # 测试用笔记本
#
# 给 **translate-code** 做功能验证用的占位内容，不是正式文档。

# %%
"""代码格顶上的小说明：算个数列的平均值。"""
# 用标准库就行
from statistics import mean
xs = [2, 4, 6, 8, 10]
print('avg:', mean(xs))

# %%
# 斐波那契：迭代写法，避免递归太深
def fib(n):
    a, b = 0, 1
    for _ in range(max(0, n)):
        a, b = b, a + b
    return a
print([fib(i) for i in range(10)])
